# %%
import pandas as pd 

df = pd.read_csv("spiked_v2_final_summary.csv")

# %%
# df[(df['model_class'] == 'VanillaSAE') & (df['rho'] == 0)][['l0_active_features', 'dead_neurons_pct', 'explained_variance']]
# Out:
#      l0_active_features  dead_neurons_pct  explained_variance
# 233          325.316406          0.000000            0.972487
# 234           51.308594          0.000000            0.884206
# 235           21.324219          1.660156            0.723210
# 236            0.500000         13.867188            0.016295

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 79 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Name                                       237 non-null    object
#  1   l0_active_features                         237 non-null    float64
#  2   State                                      237 non-null    object
#  3   Notes                                      237 non-null    object
#  4   User                                       0 non-null      float64
#  5   Tags                                       237 non-null    object
#  6   Created                                    237 non-null    object
#  7   Runtime                                    237 non-null    int64
#  8   Sweep                                      0 non-null      float64
#  9   batch_size                                 237 non-null    int64
# ...

# %%
df_filtered = df[(df['l0_active_features'] >= 2) & (df['rho'] == 0.9)].copy()

# %%
best_runs = df_filtered.loc[df_filtered.groupby('model_class')['l0_active_features'].apply(lambda x: (x - 16).abs().idxmin())]
best_runs[['model_class', 'l0_active_features', 'dead_neurons_pct', 'explained_variance', 'code_recovery_l2', 'dictionary_error_frobenius', 'support_f1_score', 'support_precision', 'support_recall']]
# Out:
#                model_class  l0_active_features  dead_neurons_pct  \
# 19   AdaptiveElasticNetSAE           18.402344         43.359375
# 91        AdaptiveLassoSAE           17.085938         51.464844
# 115          ElasticNetSAE           13.351562         81.542969
# 12                 TopKSAE           14.941406         98.144531
# 7               VanillaSAE           17.265625         67.675781
#
#      explained_variance  code_recovery_l2  dictionary_error_frobenius  \
# 19             0.672843          7.823472                   40.602325
# 91             0.645039          8.118853                   41.376663
# 115            0.328889          8.308116                   44.394165
# 12             0.449735         14.311655                   44.348236
# 7              0.533119          8.148271                   42.563606
#
#      support_f1_score  support_precision  support_recall
# 19           0.399682           0.373594        0.429687
# ...
